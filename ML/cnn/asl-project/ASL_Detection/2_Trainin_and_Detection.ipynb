# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
#PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
#PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v1_coco_11_06_2017.tar.gz'
#PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# !pip install grpcio==1.44.0
# Out:
# Requirement already satisfied: grpcio==1.44.0 in ./tfod/lib/python3.10/site-packages (1.44.0)
# Requirement already satisfied: six>=1.5.2 in ./tfod/lib/python3.10/site-packages (from grpcio==1.44.0) (1.16.0)

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# /bin/bash: apt-get: command not found
# Processing /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/Tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.46.0)
# Requirement already satisfied: pillow in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (9.4.0)
# Requirement already satisfied: lxml in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (0.29.33)
# Requirement already satisfied: contextlib2 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.0.6)
# Requirement already satisfied: lvis in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.5.3)
# Requirement already satisfied: tf-models-official>=2.5.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.11.5)
# Requirement already satisfied: tensorflow_io in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (0.31.0)
# Requirement already satisfied: keras in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.11.0)
# Requirement already satisfied: pyparsing==2.4.7 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: colorama in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.22.4)
# Requirement already satisfied: regex in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.3.23)
# Requirement already satisfied: portalocker in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.7.0)
# Requirement already satisfied: immutabledict in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.2.3)
# Requirement already satisfied: gin-config in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: psutil>=5.4.3 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.4)
# Requirement already satisfied: opencv-python-headless in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: tensorflow-addons in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.19.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.7.3)
# Requirement already satisfied: tensorflow-text~=2.11.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: seqeval in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: kaggle>=1.3.9 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.13)
# Requirement already satisfied: sentencepiece in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.97)
# Requirement already satisfied: tensorflow-datasets in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.3)
# Requirement already satisfied: oauth2client in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Requirement already satisfied: tensorflow~=2.11.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.11.1)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.1)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.82.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from pandas->object-detection==0.1) (2023.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: absl-py>=0.2.2 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: typing-extensions>=3.7.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.6.1)
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (2.28.2)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: cloudpickle~=2.2.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (3.13.0)
# Requirement already satisfied: protobuf<3.19.5,>3.12.2 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (3.19.4)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.20.0)
# Requirement already satisfied: orjson<4.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (3.8.8)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.7.3)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.44.0)
# Requirement already satisfied: pyarrow<10.0.0,>=3.0.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.18)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: kiwisolver>=1.1.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from matplotlib->object-detection==0.1) (4.39.2)
# Requirement already satisfied: packaging>=20.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from matplotlib->object-detection==0.1) (23.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.31.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow_io->object-detection==0.1) (0.31.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.16.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: docopt in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: python-slugify in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: certifi in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: tqdm in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.65.0)
# Requirement already satisfied: urllib3 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (23.3.3)
# Requirement already satisfied: h5py>=2.9.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.11.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: setuptools in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (58.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: dm-tree~=0.1.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: rsa>=3.1.4 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: scikit-learn>=0.21.3 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: typeguard>=2.7 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (3.0.2)
# Requirement already satisfied: toml in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: promise in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.12.0)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.1.1)
# Requirement already satisfied: click in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.40.0)
# Requirement already satisfied: importlib_resources in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.12.0)
# Requirement already satisfied: zipp in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1655344 sha256=7994101bcaed8f8599984dc2e637d4610cff493c0691e2aecc321d5e986a3c1b
#   Stored in directory: /private/var/folders/5g/zx4jsxj11zgbw_lq_156xzl00000gn/T/pip-ephem-wheel-cache-ghj6iiht/wheels/85/12/ea/07349e27f6ee20c44e9766698ede99ae89e8f1df358ad4bb02
# Successfully built object-detection
# Installing collected packages: object-detection
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed object-detection-0.1

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2023-03-26 19:54:33.992906: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Running tests under Python 3.10.2: /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/bin/python
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-03-26 19:54:48.105712: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/olivia/Dropbox/Coding/Python/ML/cnn/asl-project/ASL_Detection/tfod/lib/python3.10/site-packages/object_detection/builders/model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0326 19:54:48.566395 4777807360 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.82s
# I0326 19:54:48.918469 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.82s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.24s
# I0326 19:54:50.160445 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.24s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.32s
# I0326 19:54:50.481844 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.32s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.43s
# I0326 19:54:50.913109 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.43s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 3.43s
# I0326 19:54:54.348387 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 3.43s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0326 19:54:54.357145 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.06s
# I0326 19:54:54.416800 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.07s
# I0326 19:54:54.489082 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.1s
# I0326 19:54:54.593759 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.33s
# I0326 19:54:54.924226 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.33s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.36s
# I0326 19:54:55.288814 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.36s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.34s
# I0326 19:54:55.624823 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.34s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.15s
# I0326 19:54:55.772510 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.15s
# I0326 19:54:55.923444 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.06s
# I0326 19:54:55.988468 4777807360 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0326 19:54:56.262111 4777807360 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0326 19:54:56.262241 4777807360 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0326 19:54:56.262301 4777807360 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations:
test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 52.060s
#
# OK (skipped=1)

# %%
# !pip install tensorflow --upgrade

# %%
# This worked for the following error: ImportError: cannot import name 'builder' from 'google.protobuf.internal'
# **** I had to run everything within the terminal outside of the Jupyter notebook **** 
# version that this project uses: 3.19.4
# https://stackoverflow.com/questions/71759248/importerror-cannot-import-name-builder-from-google-protobuf-internal

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# absl-py                       1.4.0
# apache-beam                   2.46.0
# appnope                       0.1.3
# asttokens                     2.2.1
# astunparse                    1.6.3
# avro-python3                  1.10.2
# backcall                      0.2.0
# cachetools                    5.3.0
# certifi                       2022.12.7
# charset-normalizer            3.1.0
# click                         8.1.3
# cloudpickle                   2.2.1
# colorama                      0.4.6
# comm                          0.1.3
# contextlib2                   21.6.0
# contourpy                     1.0.7
# crcmod                        1.7
# cycler                        0.11.0
# Cython                        0.29.33
# debugpy                       1.6.6
# decorator                     5.1.1
# dill                          0.3.1.1
# dm-tree                       0.1.8
# docopt                        0.6.2
# etils                         1.1.1
# executing                     1.2.0
# fastavro                      1.7.3
# fasteners                     0.18
# flatbuffers                   23.3.3
# fonttools                     4.39.2
# gast                          0.4.0
# gin-config                    0.5.0
# google-api-core               2.8.2
# google-api-python-client      2.82.0
# google-auth                   2.16.3
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# googleapis-common-protos      1.56.4
# grpcio                        1.44.0
# h5py                          3.8.0
# hdfs                          2.7.0
# httplib2                      0.21.0
# idna                          3.4
# immutabledict                 2.2.3
# importlib-resources           5.12.0
# ipykernel                     6.22.0
# ipython                       8.11.0
# jedi                          0.18.2
# joblib                        1.2.0
# jupyter_client                8.1.0
# jupyter_core                  5.3.0
# kaggle                        1.5.13
# keras                         2.11.0
# kiwisolver                    1.4.4
# libclang                      16.0.0
# lvis                          0.5.3
# lxml                          4.9.2
# Markdown                      3.4.3
# MarkupSafe                    2.1.2
# matplotlib                    3.7.1
# matplotlib-inline             0.1.6
# nest-asyncio                  1.5.6
# numpy                         1.22.4
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# object-detection              0.1
# objsize                       0.6.1
# opencv-python                 4.7.0.72
# opencv-python-headless        4.7.0.72
# opt-einsum                    3.3.0
# orjson                        3.8.8
# packaging                     23.0
# pandas                        1.5.3
# parso                         0.8.3
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           23.0.1
# platformdirs                  3.2.0
# portalocker                   2.7.0
# promise                       2.3
# prompt-toolkit                3.0.38
# proto-plus                    1.22.2
# protobuf                      3.19.4
# psutil                        5.9.4
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyarrow                       9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.6
# pydot                         1.4.2
# Pygments                      2.14.0
# pymongo                       3.13.0
# pyparsing                     2.4.7
# python-dateutil               2.8.2
# python-slugify                8.0.1
# pytz                          2023.2
# PyYAML                        5.4.1
# pyzmq                         25.0.2
# regex                         2023.3.23
# requests                      2.28.2
# requests-oauthlib             1.3.1
# rsa                           4.9
# sacrebleu                     2.2.0
# scikit-learn                  1.2.2
# scipy                         1.10.1
# sentencepiece                 0.1.97
# seqeval                       1.2.2
# setuptools                    58.1.0
# six                           1.16.0
# stack-data                    0.6.2
# tabulate                      0.9.0
# tensorboard                   2.11.2
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.11.1
# tensorflow-addons             0.19.0
# tensorflow-datasets           4.8.3
# tensorflow-estimator          2.11.0
# tensorflow-hub                0.12.0
# tensorflow-io                 0.31.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-metadata           1.12.0
# tensorflow-model-optimization 0.7.3
# tensorflow-text               2.11.0
# termcolor                     2.2.0
# text-unidecode                1.3
# tf-models-official            2.11.5
# tf-slim                       1.1.0
# threadpoolctl                 3.1.0
# toml                          0.10.2
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.9.0
# typeguard                     3.0.2
# typing_extensions             4.5.0
# uritemplate                   4.1.1
# urllib3                       1.26.15
# wcwidth                       0.2.6
# Werkzeug                      2.2.3
# wheel                         0.40.0
# wrapt                         1.15.0
# zipp                          3.15.0
# zstandard                     0.20.0

# %%
# Download pretrained (COCO) model from Tensorflow Model Zoo (using the SSD_MobileNet model)
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2023-03-26 20:13:31--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.9.128
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.9.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20518283 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.57M  5.52MB/s    in 3.9s
#
# 2023-03-26 20:13:35 (5.06 MB/s) - ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’ saved [20518283/20518283]
#
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
#print(files['LABELMAP'])

# %%
labels = [{'name':'A', 'id':1}, {'name':'B', 'id':2}, {'name':'C', 'id':3}, {'name':'D', 'id':4}]#, {'name':'E', 'id':5}, {'name':'F', 'id':6}, {'name':'G', 'id':7}, {'name':'H', 'id':8}, {'name':'I', 'id':9}, {'name':'J', 'id':10}, {'name':'K', 'id':11}, {'name':'L', 'id':12}, {'name':'M', 'id':13}, {'name':'N', 'id':14}, {'name':'O', 'id':15}, {'name':'P', 'id':16}, {'name':'Q', 'id':17}, {'name':'R', 'id':18}, {'name':'S', 'id':19}, {'name':'T', 'id':20}, {'name':'U', 'id':21}, {'name':'V', 'id':22}, {'name':'W', 'id':23}, {'name':'X', 'id':24}, {'name':'Y', 'id':25}, {'name':'Z', 'id':26}, {'name':'space', 'id':27}, {'name':'delete', 'id':28}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
files['PIPELINE_CONFIG']
# Out:
# 'Tensorflow/workspace/models/my_ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config'

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=1000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8 --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config --num_train_steps=1000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8 --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-2')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'D.3882c960-c9bc-11ed-8ceb-38f9d362366a.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y
# Out:
# Found existing installation: opencv-python-headless 4.7.0.72
# Uninstalling opencv-python-headless-4.7.0.72:
#   Successfully uninstalled opencv-python-headless-4.7.0.72

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
